# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayak-Sharma12/Kaggle_99Acre_HousingData/blob/main/99Acre_DataSet_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### **DATA PREPROCESSING OF FLAT CSV**

# %%
df1=pd.read_csv('flats.csv')

# %%
df1.head(10)
# Out:
#                              property_name  \
# 0             2 BHK Flat in Krishna Colony
# 1                2 BHK Flat in Ashok Vihar
# 2                      2 BHK Flat in Sohna
# 3          2 BHK Flat in Sector 61 Gurgaon
# 4          2 BHK Flat in Sector 92 Gurgaon
# 5          2 BHK Flat in Sector 36 Gurgaon
# 6  3 BHK Flat in Dwarka Expressway Gurgaon
# 7         3 BHK Flat in Sector 104 Gurgaon
# 8         2 BHK Flat in Sector 88B Gurgaon
# 9          3 BHK Flat in Sector 78 Gurgaon
#
#                                                 link  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 5  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 6  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 7  https://www.99acres.com/3-bhk-bedroom-apartmen...
# ...

# %%
df1.drop(columns=['link'],inplace=True)

# %%
df1.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               rate                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
print(df1.columns)
# Out:
# Index(['property_name', 'society', 'price', 'rate', 'areaWithType', 'bedRoom',
#        'bathroom', 'balcony', 'additionalRoom', 'address', 'floorNum',
#        'facing', 'agePossession', 'nearbyLocations', 'description',
#        'furnishDetails', 'features', 'rating', 'property_id'],
#       dtype='object')

# %%
df1.shape
# Out:
# (3017, 19)

# %%
print(df1.isnull().sum())
# Out:
# property_name         0
# society               1
# price                10
# rate                 13
# areaWithType          9
# bedRoom               9
# bathroom              9
# balcony               9
# additionalRoom     1323
# address              15
# floorNum             11
# facing              890
# agePossession        10
# nearbyLocations     104
# description           9
# furnishDetails      814
# features            423
# rating              341
# property_id           9
# dtype: int64

# %%
df1['additionalRoom']=df1['additionalRoom'].fillna('No Additional Room')

# %%
df1['furnishDetails']=df1['furnishDetails'].fillna('No furnishing Details available')

# %%
df1['facing']=df1['facing'].fillna('Not Mentioned')

# %%
df1.isnull().sum()
# Out:
# property_name        0
# society              1
# price               10
# rate                13
# areaWithType         9
# bedRoom              9
# bathroom             9
# balcony              9
# additionalRoom       0
# address             15
# floorNum            11
# facing               0
# agePossession       10
# nearbyLocations    104
# description          9
# furnishDetails       0
# features           423
# rating             341
# property_id          9
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (2306, 19)

# %%
print(df1.isnull().sum())
# Out:
# property_name      0
# society            0
# price              0
# rate               0
# areaWithType       0
# bedRoom            0
# bathroom           0
# balcony            0
# additionalRoom     0
# address            0
# floorNum           0
# facing             0
# agePossession      0
# nearbyLocations    0
# description        0
# furnishDetails     0
# features           0
# rating             0
# property_id        0
# dtype: int64

# %%
df1.head()
# Out:
#                       property_name                 society       price  \
# 0      2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1         2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2               2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 7  3 BHK Flat in Sector 104 Gurgaon        ATS Triumph3.9 ★   1.8 Crore
# 9   3 BHK Flat in Sector 78 Gurgaon          Raheja Revanta  4.75 Crore
#
#               rate                        areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.      Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.      Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.      Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 7   ₹ 7,860/sq.ft.    Carpet area: 2290 (212.75 sq.m.)  3 Bedrooms
# 9  ₹ 16,885/sq.ft.  Built Up area: 2813 (261.34 sq.m.)  3 Bedrooms
#
#       bathroom      balcony      additionalRoom  \
# 0  2 Bathrooms    1 Balcony  No Additional Room
# ...

# %%
df1[df1['furnishDetails']=='[]']
# Out:
#                          property_name  \
# 7     3 BHK Flat in Sector 104 Gurgaon
# 17    2 BHK Flat in Sector 102 Gurgaon
# 45                 3 BHK Flat in Sohna
# 64    3 BHK Flat in Sector 37D Gurgaon
# 66    3 BHK Flat in Sector 37C Gurgaon
# ...                                ...
# 2969   2 BHK Flat in Sector 79 Gurgaon
# 2975   2 BHK Flat in Sector 90 Gurgaon
# 2979  2 BHK Flat in Sector 99A Gurgaon
# 2981   2 BHK Flat in Sector 81 Gurgaon
# 2991   3 BHK Flat in Sector 79 Gurgaon
#
#                                         society       price             rate  \
# 7                              ATS Triumph3.9 ★   1.8 Crore   ₹ 7,860/sq.ft.
# 17    Shapoorji Pallonji Joyville Gurugram4.0 ★  1.05 Crore  ₹ 11,475/sq.ft.
# 45                   Signature Global Park4.0 ★      95 Lac   ₹ 7,846/sq.ft.
# 64                              Ramprastha Skyz   1.1 Crore   ₹ 6,376/sq.ft.
# 66                              ILD Greens4.1 ★     1 Crore   ₹ 4,320/sq.ft.
# ...

# %%
df1['furnishDetails']=df1['furnishDetails'].replace('[]','No furnishing Details available')

# %%
df1.head()
# Out:
#                       property_name                 society       price  \
# 0      2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1         2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2               2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 7  3 BHK Flat in Sector 104 Gurgaon        ATS Triumph3.9 ★   1.8 Crore
# 9   3 BHK Flat in Sector 78 Gurgaon          Raheja Revanta  4.75 Crore
#
#               rate                        areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.      Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.      Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.      Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 7   ₹ 7,860/sq.ft.    Carpet area: 2290 (212.75 sq.m.)  3 Bedrooms
# 9  ₹ 16,885/sq.ft.  Built Up area: 2813 (261.34 sq.m.)  3 Bedrooms
#
#       bathroom      balcony      additionalRoom  \
# 0  2 Bathrooms    1 Balcony  No Additional Room
# ...

# %% [markdown]
# ## **DATA PREPROCESSING OF HOUSE CSV**

# %%
df2=pd.read_csv("houses.csv")

# %%
df2.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df2.drop(columns=['link'],inplace=True)

# %%
df2.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df2.shape
# Out:
# (1044, 20)

# %%
df2.isnull().sum()
# Out:
# property_name        0
# society            591
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom     455
# address             13
# noOfFloor           77
# facing             370
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails     301
# features           370
# rating             137
# property_id          8
# dtype: int64

# %%
df2['additionalRoom']=df2['additionalRoom'].fillna('No Additional Room')

# %%
df2['furnishDetails']=df2['furnishDetails'].fillna('No furnishing Details available')

# %%
df2['furnishDetails']=df2['furnishDetails'].fillna('No furnishing Details available')

# %%
df2['facing']=df2['facing'].fillna('Not Mentioned')

# %%
df2.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df2.isnull().sum()
# Out:
# property_name        0
# society            591
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom       0
# address             13
# noOfFloor           77
# facing               0
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails       0
# features           370
# rating             137
# property_id          8
# dtype: int64

# %%
df2['society']=df2['society'].fillna('Not available ')

# %%
df2['features']=df2['features'].fillna('No feature mentioned')

# %%
print(df2.isnull().sum())
# Out:
# property_name        0
# society              0
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom       0
# address             13
# noOfFloor           77
# facing               0
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails       0
# features             0
# rating             137
# property_id          8
# dtype: int64

# %%
df2.shape
# Out:
# (1044, 20)

# %%
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (729, 20)

# %%
df2.head(30)
# Out:
#                                         property_name  \
# 0      5 Bedroom House for sale in Sector 70A Gurgaon
# 2    10 Bedroom House for sale in Sushant Lok Phase 1
# 3      21 Bedroom House for sale in Sector 54 Gurgaon
# 4    12 Bedroom House for sale in Sushant Lok Phase 1
# 5    20 Bedroom House for sale in Sushant Lok Phase 1
# 6       5 Bedroom House for sale in Sector 66 Gurgaon
# 7            16 Bedroom House for sale in DLF Phase 1
# 8             6 Bedroom House for sale in DLF Phase 2
# 9     3 Bedroom House for sale in Sushant Lok Phase 1
# 10            4 Bedroom House for sale in DLF Phase 2
# 11            6 Bedroom House for sale in DLF Phase 4
# 12           13 Bedroom House for sale in DLF Phase 3
# 13            5 Bedroom House for sale in DLF Phase 1
# 14  5 Bedroom House for sale in B Block Sushant Lo...
# 16            9 Bedroom House for sale in DLF Phase 2
# 17      7 Bedroom House for sale in Sector 38 Gurgaon
# ...

# %%
df2.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad    Not available
# 2  10 Bedroom House for sale in Sushant Lok Phase 1    Not available
# 3    21 Bedroom House for sale in Sector 54 Gurgaon    Not available
# 4  12 Bedroom House for sale in Sushant Lok Phase 1    Not available
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %% [markdown]
# ### **SAVE FILES**

# %%
df1.to_csv('new_flats.csv')
df2.to_csv('new_houses.csv')
